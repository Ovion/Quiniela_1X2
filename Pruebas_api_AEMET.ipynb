# %%
import pandas as pd

# %%
df = pd.read_csv('data/Temp15-16.csv')
df1 = pd.read_csv('data/Temp16-17.csv')
df2 = pd.read_csv('data/Temp17-18.csv')
df.head()
# Out:
#              Equipo Local  Goles  Ataque  Medio  Defensa  Goles_Acumulados  \
# 0                  Málaga      0      75     76       75                 0
# 1  Deportivo de La Coruña      0      79     74       74                 0
# 2                Espanyol      1      76     75       74                 0
# 3      Atlético de Madrid      1      81     80       81                 0
# 4          Rayo Vallecano      0      75     75       74                 0
#
#   Equipo Visitante  Goles.1  Ataque.1  Medio.1  Defensa.1  Goles_Acumulados.1  \
# 0          Sevilla        0        79       80         80                   0
# 1    Real Sociedad        0        77       77         76                   0
# 2           Getafe        0        73       75         74                   0
# 3       Las Palmas        0        73       71         70                   0
# 4         Valencia        0        79       80         79                   0
#
#           Día   Hora  Jornada  Resultado
# 0  21/08/2015  20:30        1          1
# 1  22/08/2015  18:30        1          1
# 2  22/08/2015  18:30        1          2
# 3  22/08/2015  20:30        1          2
# 4  22/08/2015  22:30        1          1

# %%
lst_eq0 = list(df['Equipo Local'].unique())
lst_eq1 = list(df1['Equipo Local'].unique())
lst_eq2 = list(df2['Equipo Local'].unique())

lst_eq = list(set(lst_eq0 + lst_eq1 + lst_eq2))
for eq in lst_eq:
    print(eq)
# Out:
# Espanyol
# Athletic Club
# Betis
# Eibar
# Getafe
# Girona
# Atlético de Madrid
# Deportivo de La Coruña
# Celta de Vigo
# Osasuna
# Real Sociedad
# Barcelona
# Granada
# Sporting de Gijón
# Villarreal
# Sevilla
# Leganés
# Málaga
# Alavés
# Real Madrid
# Levante
# Las Palmas
# Rayo Vallecano
# Valencia

# %%
est_meteo = {
'Eibar': {'prov':'Gipuzkoa',
         'cod_est':'1050J'},
'Granada': {'prov':'Granada',
            'cod_est':'5530E'},
'Sporting de Gijón': {'prov':'Asturias',
                      'cod_est':'1207U'},
'Girona': {'prov':'Girona',
           'cod_est':'0367'},
'Espanyol': {'prov':'Barcelona',
             'cod_est':'0076'},
'Rayo Vallecano': {'prov':'Madrid',
                   'cod_est':'3195'},
'Athletic Club': {'prov':'Bizkaia',
                  'cod_est':'1082'},
'Alavés': {'prov':'Araba',
           'cod_est':'9091R'},
'Osasuna': {'prov':'Navarra',
            'cod_est':'9263D'},
'Deportivo de La Coruña': {'prov':'A Coruña',
                           'cod_est':'1387'},
'Sevilla': {'prov':'Sevilla',
            'cod_est':'5783'},
'Real Madrid': {'prov':'Madrid',
                'cod_est':'3195'},
'Leganés': {'prov':'Madrid',
            'cod_est':'3195'},
'Levante': {'prov':'Valencia',
            'cod_est':'8414A'},
'Barcelona': {'prov':'Barcelona',
              'cod_est':'0076'},
'Getafe': {'prov':'Madrid',
           'cod_est':'3195'},
'Málaga': {'prov':'Málaga',
           'cod_est':'6106X'},
'Villarreal': {'prov':'Castellón',
               'cod_est':'8500A'},
'Atlético de Madrid': {'prov':'Madrid',
                       'cod_est':'3195'},
'Real Sociedad': {'prov':'Gipuzkoa',
                  'cod_est':'1014A'},
'Las Palmas': {'prov':'Las Palmas',
               'cod_est':'C659M'},
'Celta de Vigo': {'prov':'Pontevedra',
         'cod_est':'1495'},
'Betis': {'prov':'Sevilla',
          'cod_est':'5783'},
'Valencia': {'prov':'Valencia',
             'cod_est':'8414A'}

}

# %%
df['cod_est'] = df['Equipo Local'].apply(lambda x: est_meteo[x]['cod_est'])
df1['cod_est'] = df1['Equipo Local'].apply(lambda x: est_meteo[x]['cod_est'])
df2['cod_est'] = df2['Equipo Local'].apply(lambda x: est_meteo[x]['cod_est'])

df['Día'] =  pd.to_datetime(df['Día'], format='%d/%m/%Y')
df['Día'] = df.Día.dt.strftime('%Y-%m-%d')
df1['Día'] =  pd.to_datetime(df1['Día'], format='%d/%m/%Y')
df1['Día'] = df1.Día.dt.strftime('%Y-%m-%d')
df2['Día'] =  pd.to_datetime(df2['Día'], format='%d/%m/%Y')
df2['Día'] = df2.Día.dt.strftime('%Y-%m-%d')

# %%
df.head()
# Out:
#              Equipo Local  Goles  Ataque  Medio  Defensa  Goles_Acumulados  \
# 0                  Málaga      0      75     76       75                 0
# 1  Deportivo de La Coruña      0      79     74       74                 0
# 2                Espanyol      1      76     75       74                 0
# 3      Atlético de Madrid      1      81     80       81                 0
# 4          Rayo Vallecano      0      75     75       74                 0
#
#   Equipo Visitante  Goles.1  Ataque.1  Medio.1  Defensa.1  Goles_Acumulados.1  \
# 0          Sevilla        0        79       80         80                   0
# 1    Real Sociedad        0        77       77         76                   0
# 2           Getafe        0        73       75         74                   0
# 3       Las Palmas        0        73       71         70                   0
# 4         Valencia        0        79       80         79                   0
#
#           Día   Hora  Jornada  Resultado cod_est
# 0  2015-08-21  20:30        1          1   6106X
# 1  2015-08-22  18:30        1          1    1387
# 2  2015-08-22  18:30        1          2    0076
# 3  2015-08-22  20:30        1          2    3195
# 4  2015-08-22  22:30        1          1    3195

# %%
import os
from dotenv import load_dotenv
import json
import re
import requests
import time

import swagger_client
from swagger_client.rest import ApiException

# %%
requests.packages.urllib3.util.ssl_.DEFAULT_CIPHERS += 'HIGH:!DH:!aNULL'
try:
    requests.packages.urllib3.contrib.pyopenssl.DEFAULT_SSL_CIPHER_LIST += 'HIGH:!DH:!aNULL'
except AttributeError:
    # no pyopenssl support used / needed / available
    pass

# %%
load_dotenv()
AEMET_KEY = os.getenv("KEY_AEMET")
configuration = swagger_client.Configuration()
configuration.api_key['api_key'] = AEMET_KEY

# %%
fecha_ini = '2018-02-05T00:00:00UTC'
fecha_fin = '2018-02-05T23:59:59UTC'
estacion = '9091R'

#url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{estacion}/?api_key={AEMET_KEY}"

# %%
api_instance = swagger_client.ValoresClimatologicosApi(swagger_client.ApiClient(configuration))

# %%
try:
    respuesta_api = api_instance.climatologas_diarias_(fecha_ini, fecha_fin, estacion)
    print (respuesta_api)
    print('\n\n')
    url_respuesta = respuesta_api.datos
    response = requests.request("GET", url_respuesta)
    print(response)
    print('\n\n')
    meteo = json.loads(response.text)[0]
    print (meteo)
except ApiException as e:
    print ('Algo ha fallado')
# Out:
# {'datos': 'https://opendata.aemet.es/opendata/sh/119c2f38',
#  'descripcion': 'exito',
#  'estado': 200,
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#
#
# <Response [200]>
#
#
#
# {'fecha': '2018-02-05', 'indicativo': '9091R', 'nombre': 'VITORIA GASTEIZ AEROPUERTO', 'provincia': 'ARABA/ALAVA', 'altitud': '513', 'tmed': '2,6', 'prec': '0,5', 'tmin': '1,7', 'horatmin': '18:10', 'tmax': '3,6', 'horatmax': '13:30', 'dir': '36', 'velmedia': '3,6', 'racha': '11,7', 'horaracha': '23:34', 'sol': '0,0', 'presMax': '953,8', 'horaPresMax': 'Varias', 'presMin': '949,9', 'horaPresMin': '04'}

# %%
few = df2
for index, row in few.iterrows():
    print(index)
    fecha_ini = row.Día + 'T00:00:00UTC'
    fecha_fin = row.Día + 'T23:59:59UTC'
    estacion = row.cod_est
    
    try:
        respuesta_api = api_instance.climatologas_diarias_(fecha_ini, fecha_fin, estacion)
        print (respuesta_api)
        print('\n\n')
        url_respuesta = respuesta_api.datos
        response = requests.request("GET", url_respuesta)
        print(response)
        print('\n\n')
        meteo = json.loads(response.text)[0]
        print (meteo)
        
        try:
            few.loc[index, 'tmin'] = meteo['tmin']
        except:
            few.loc[index, 'tmin'] = '-'
        try:
            few.loc[index, 'tmed'] = meteo['tmed']
        except:
            few.loc[index, 'tmed'] = '-'
        try:
            few.loc[index, 'tmax'] = meteo['tmax']
        except:
            few.loc[index, 'tmax'] = '-'
        try:
            few.loc[index, 'prec'] = meteo['prec']
        except:
            few.loc[index, 'prec'] = '-'
        try:
            few.loc[index, 'presmin'] = meteo['presMin']
        except:
            few.loc[index, 'presmin'] = '-'
        try:
            few.loc[index, 'presmax'] = meteo['presMax']
        except:
            few.loc[index, 'presmax'] = '-'
        try:
            few.loc[index, 'velmedia'] = meteo['velmedia']
        except:
            few.loc[index, 'velmedia'] = '-'
        try:
            few.loc[index, 'rachaviento'] = meteo['racha']
        except:
            few.loc[index, 'rachaviento'] = '-'
        
        time.sleep(2)
    except ApiException as e:
        print ('Algo ha fallado')
# Out:
# 0
# {'datos': 'https://opendata.aemet.es/opendata/sh/4c6dbb16',
#  'descripcion': 'exito',
#  'estado': 200,
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#
#
# <Response [200]>
#
#
#
# {'fecha': '2017-08-18', 'indicativo': '8414A', 'nombre': 'VALENCIA AEROPUERTO', 'provincia': 'VALENCIA', 'altitud': '56', 'tmed': '27,2', 'prec': '0,0', 'tmin': '21,9', 'horatmin': '05:29', 'tmax': '32,5', 'horatmax': '11:22', 'dir': '04', 'velmedia': '3,9', 'racha': '9,7', 'horaracha': 'Varias', 'sol': '12,0', 'presMax': '1011,3', 'horaPresMax': '00', 'presMin': '1005,9', 'horaPresMin': '16'}
# 1
# {'datos': 'https://opendata.aemet.es/opendata/sh/881b2633',
#  'descripcion': 'exito',
#  'estado': 200,
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#
#
# <Response [200]>
#
#
#
# {'fecha': '2017-08-18', 'indicativo': '3195', 'nombre': 'MADRID, RETIRO', 'provincia': 'MADRID', 'altitud': '667', 'tmed': '30,1', 'prec': '0,0', 'tmin': '23,6', 'horatmin': '07:00', 'tmax': '36,6', 'horatmax': '14:10', 'dir': '05', 'velmedia': '1,9', 'racha': '8,1', 'horaracha': '23:00', 'presMax': '942,4', 'horaPresMax': '08', 'presMin': '938,1', 'horaPresMin': '17'}
# 2
# {'datos': 'https://opendata.aemet.es/opendata/sh/e4cf937f',
#  'descripcion': 'exito',
#  'estado': 200,
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#
#
# <Response [200]>
#
#
#
# {'fecha': '2017-08-19', 'indicativo': '1495', 'nombre': 'VIGO AEROPUERTO', 'provincia': 'PONTEVEDRA', 'altitud': '261', 'tmed': '23,0', 'prec': '0,0', 'tmin': '14,1', 'horatmin': '05:42', 'tmax': '31,8', 'horatmax': '13:55', 'dir': '35', 'velmedia': '3,6', 'racha': '11,7', 'horaracha': '17:23', 'presMax': '991,3', 'horaPresMax': 'Varias', 'presMin': '989,3', 'horaPresMin': '16'}
# 3
# {'datos': 'https://opendata.aemet.es/opendata/sh/cbd1a2aa',
#  'descripcion': 'exito',
#  'estado': 200,
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#
#
# <Response [200]>
#
#
#
# {'fecha': '2017-08-19', 'indicativo': '0367', 'nombre': 'GIRONA AEROPUERTO', 'provincia': 'GIRONA', 'altitud': '143', 'tmed': '25,0', 'prec': '0,0', 'tmin': '20,0', 'horatmin': '06:03', 'tmax': '30,1', 'horatmax': '13:12', 'dir': '20', 'velmedia': '2,5', 'racha': '8,3', 'horaracha': '13:14', 'sol': '5,4', 'presMax': '1004,8', 'horaPresMax': 'Varias', 'presMin': '1001,2', 'horaPresMin': '01'}
# 4
# {'datos': 'https://opendata.aemet.es/opendata/sh/6b46cdae',
#  'descripcion': 'exito',
#  'estado': 200,
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#
#
# <Response [200]>
#
#
#
# {'fecha': '2017-08-19', 'indicativo': '5783', 'nombre': 'SEVILLA AEROPUERTO', 'provincia': 'SEVILLA', 'altitud': '34', 'tmed': '31,4', 'prec': '0,0', 'tmin': '22,4', 'horatmin': '05:06', 'tmax': '40,4', 'horatmax': '14:57', 'dir': '21', 'velmedia': '3,3', 'racha': '10,3', 'horaracha': '16:53', 'sol': '12,1', 'presMax': '1011,4', 'horaPresMax': 'Varias', 'presMin': '1008,4', 'horaPresMin': '17'}
# 5
# {'datos': 'https://opendata.aemet.es/opendata/sh/e32837ff',
#  'descripcion': 'exito',
#  'estado': 200,
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#
#
# <Response [200]>
#
#
#
# {'fecha': '2017-08-20', 'indicativo': '1082', 'nombre': 'BILBAO AEROPUERTO', 'provincia': 'BIZKAIA', 'altitud': '42', 'tmed': '19,4', 'prec': '0,0', 'tmin': '12,7', 'horatmin': '05:42', 'tmax': '26,1', 'horatmax': '12:40', 'dir': '04', 'velmedia': '2,8', 'racha': '8,9', 'horaracha': '14:29', 'sol': '12,2', 'presMax': '1022,0', 'horaPresMax': 'Varias', 'presMin': '1018,4', 'horaPresMin': '24'}
# 6
# {'datos': 'https://opendata.aemet.es/opendata/sh/08fbba21',
#  'descripcion': 'exito',
#  'estado': 200,
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
#
#
# <Response [200]>
#
#
#
# {'fecha': '2017-08-20', 'indicativo': '0076', 'nombre': 'BARCELONA AEROPUERTO', 'provincia': 'BARCELONA', 'altitud': '4', 'tmed': '26,0', 'prec': '0,5', 'tmin': '23,7', 'horatmin': '23:52', 'tmax': '28,2', 'horatmax': '12:21', 'dir': '21', 'velmedia': '3,6', 'racha': '8,3', 'horaracha': '13:13', 'sol': '3,6', 'presMax': '1021,4', 'horaPresMax': 'Varias', 'presMin': '1018,9', 'horaPresMin': '18'}
# 2020-07-05 21:15:55,900 WARNING Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe90b33fb50>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /opendata/api/valores/climatologicos/diarios/datos/fechaini/2017-08-20T00%3A00%3A00UTC/fechafin/2017-08-20T23%3A59%3A59UTC/estacion/1387
# 2020-07-05 21:15:55,902 WARNING Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe8cc7d4c10>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /opendata/api/valores/climatologicos/diarios/datos/fechaini/2017-08-20T00%3A00%3A00UTC/fechafin/2017-08-20T23%3A59%3A59UTC/estacion/1387
# 2020-07-05 21:15:55,904 WARNING Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe8cc7d4f10>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /opendata/api/valores/climatologicos/diarios/datos/fechaini/2017-08-20T00%3A00%3A00UTC/fechafin/2017-08-20T23%3A59%3A59UTC/estacion/1387
# 7
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# /usr/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     975         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 976             conn.connect()
#     977
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     307         # Add certificate verification
# --> 308         conn = self._new_conn()
#     309         hostname = self.host
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fe8cc7b3310>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-13-ce33d4726fb9> in <module>
#       7
#       8     try:
# ----> 9         respuesta_api = api_instance.climatologas_diarias_(fecha_ini, fecha_fin, estacion)
#      10         print (respuesta_api)
#      11         print('\n\n')
#
# ~/Desktop/Courses/Quiniela_1X2/swagger_client/api/valores_climatologicos_api.py in climatologas_diarias_(self, fecha_ini_str, fecha_fin_str, idema, **kwargs)
#      55             return self.climatologas_diarias__with_http_info(fecha_ini_str, fecha_fin_str, idema, **kwargs)  # noqa: E501
#      56         else:
# ---> 57             (data) = self.climatologas_diarias__with_http_info(fecha_ini_str, fecha_fin_str, idema, **kwargs)  # noqa: E501
#      58             return data
#      59
#
# ~/Desktop/Courses/Quiniela_1X2/swagger_client/api/valores_climatologicos_api.py in climatologas_diarias__with_http_info(self, fecha_ini_str, fecha_fin_str, idema, **kwargs)
#     133         auth_settings = ['api_key']  # noqa: E501
#     134
# --> 135         return self.api_client.call_api(
#     136             '/api/valores/climatologicos/diarios/datos/fechaini/{fechaIniStr}/fechafin/{fechaFinStr}/estacion/{idema}', 'GET',
#     137             path_params,
#
# ~/Desktop/Courses/Quiniela_1X2/swagger_client/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     315         """
#     316         if not async_req:
# --> 317             return self.__call_api(resource_path, method,
#     318                                    path_params, query_params, header_params,
#     319                                    body, post_params, files,
#
# ~/Desktop/Courses/Quiniela_1X2/swagger_client/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     147
#     148         # perform request and return response
# --> 149         response_data = self.request(
#     150             method, url, query_params=query_params, headers=header_params,
#     151             post_params=post_params, body=body,
#
# ~/Desktop/Courses/Quiniela_1X2/swagger_client/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     337         """Makes the HTTP request using RESTClient."""
#     338         if method == "GET":
# --> 339             return self.rest_client.GET(url,
#     340                                         query_params=query_params,
#     341                                         _preload_content=_preload_content,
#
# ~/Desktop/Courses/Quiniela_1X2/swagger_client/rest.py in GET(self, url, headers, query_params, _preload_content, _request_timeout)
#     232     def GET(self, url, headers=None, query_params=None, _preload_content=True,
#     233             _request_timeout=None):
# --> 234         return self.request("GET", url,
#     235                             headers=headers,
#     236                             _preload_content=_preload_content,
#
# ~/Desktop/Courses/Quiniela_1X2/swagger_client/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     205             # For `GET`, `HEAD`
#     206             else:
# --> 207                 r = self.pool_manager.request(method, url,
#     208                                               fields=query_params,
#     209                                               preload_content=_preload_content,
#
# ~/.local/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      73
#      74         if method in self._encode_url_methods:
# ---> 75             return self.request_encode_url(
#      76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#
# ~/.local/lib/python3.8/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# ~/.local/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     750                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     751             )
# --> 752             return self.urlopen(
#     753                 method,
#     754                 url,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     750                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     751             )
# --> 752             return self.urlopen(
#     753                 method,
#     754                 url,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     750                 "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     751             )
# --> 752             return self.urlopen(
#     753                 method,
#     754                 url,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     722                 e = ProtocolError("Connection aborted.", e)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     726             )
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     437
#     438         if new_retry.is_exhausted():
# --> 439             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     440
#     441         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='opendata.aemet.es', port=443): Max retries exceeded with url: /opendata/api/valores/climatologicos/diarios/datos/fechaini/2017-08-20T00%3A00%3A00UTC/fechafin/2017-08-20T23%3A59%3A59UTC/estacion/1387 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe8cc7b3310>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))

# %%
few.iloc[37]

# %%
few.head(23)
